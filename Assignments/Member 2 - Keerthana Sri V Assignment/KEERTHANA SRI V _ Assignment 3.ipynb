# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import the libraries
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/Flowers-Dataset.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
from IPython.display import Image
Image("../input/flowers\daisy\21652746_cc379e0eea_m.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1271         try:
# -> 1272             b64_data = b2a_base64(self.data).decode('ascii')
#    1273         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
import time
from time import perf_counter as timer
start = timer()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
print(os.listdir("../Flowers-Dataset"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-015136eb9ece> in <module>
#       4 import seaborn as sns
#       5 import os
# ----> 6 print(os.listdir("../Flowers-Dataset"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Flowers-Dataset'

# %%
from tensorflow import keras
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras import optimizers, losses
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing import image

import pickle
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# Base Path for all files
data_dir = '../input/flowers-recognition/flowers'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-ec6e475fe1aa> in <module>
#      12                                ).flow_from_directory(directory=data_dir,
#      13                                                      target_size=(300, 300),
# ---> 14                                                      subset='training',
#      15                                                     ),
#      16
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     990         follow_links=follow_links,
#     991         subset=subset,
# --> 992         interpolation=interpolation)
#     993
#     994   def flow_from_dataframe(self,
#
# ...

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.15),
    Dense(1024, activation='relu'),
    Dense(5, activation='softmax') # 5 Output Neurons for 5 Classes
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ab5285607aad> in <module>
#       1 model = Sequential([
# ----> 2     base_model,
#       3     GlobalAveragePooling2D(),
#       4     Dropout(0.15),
#       5     Dense(1024, activation='relu'),
#
# NameError: name 'base_model' is not defined

# %%
# Viewing the summary of the model
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-df7c920c2962> in <module>
#       1 # Viewing the summary of the model
# ----> 2 model.summary()
#
# NameError: name 'model' is not defined

# %%
predict("../input/flowers-dataset/test/Image_1.jpg"
# Out:
#   File "<ipython-input-14-668e36e94612>", line 1
#     predict("../input/flowers-dataset/test/Image_1.jpg"
#                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
batch_size = 32
img_height, img_width = 300, 300
input_shape = (img_height, img_width, 3)
datagen = ImageDataGenerator(rescale=1.0 / 255)
train_ds = datagen.flow_from_directory('/kaggle/input/flowers-dataset/train/', target_size=(img_height, img_width), batch_size=batch_size,class_mode='sparse', subset='training')
val_ds = datagen.flow_from_directory('/kaggle/input/flowers-dataset/test/', target_size=(img_height, img_width), batch_size=batch_size,class_mode='sparse', shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-435b5f3b8158> in <module>
#       3 input_shape = (img_height, img_width, 3)
#       4 datagen = ImageDataGenerator(rescale=1.0 / 255)
# ----> 5 train_ds = datagen.flow_from_directory('/kaggle/input/flowers-dataset/train/', target_size=(img_height, img_width), batch_size=batch_size,class_mode='sparse', subset='training')
#       6 val_ds = datagen.flow_from_directory('/kaggle/input/flowers-dataset/test/', target_size=(img_height, img_width), batch_size=batch_size,class_mode='sparse', shuffle=False)
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     990         follow_links=follow_links,
# ...

# %%
import numpy as np 
import pandas as pd 

from random import randint

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os

# %%
flowers_path = '/..../input/Flowers-Dataset/train'

# %%
classes = os.listdir(flowers_path)
classes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-71491d547312> in <module>
# ----> 1 classes = os.listdir(flowers_path)
#       2 classes
#
# FileNotFoundError: [Errno 2] No such file or directory: '/..../input/Flowers-Dataset/train'

# %%
image_size = (128, 128)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    flowers_path,
    validation_split=0.25,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode="categorical",
    class_names=classes
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-db20591a2119> in <module>
#      10     batch_size=batch_size,
#      11     label_mode="categorical",
# ---> 12     class_names=classes
#      13 )
#
# NameError: name 'classes' is not defined

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
for images, labels in train_ds.take(1):
    for i in range(15):
        ax = plt.subplot(3, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(classes[np.argmax(labels[i])])
        plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c645ee7f69bd> in <module>
#       2
#       3 plt.figure(figsize=(20, 10))
# ----> 4 for images, labels in train_ds.take(1):
#       5     for i in range(15):
#       6         ax = plt.subplot(3, 5, i + 1)
#
# NameError: name 'train_ds' is not defined
